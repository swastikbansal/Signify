# %% [markdown]
# # Importing Libraries

# %%
import cv2
import mediapipe as mp

import matplotlib.pyplot as plt
import numpy as np

import random
import os
from tqdm.notebook import tqdm

import utils

from glob import glob
import IPython.display as ipd

# %% [markdown]
# # Extracting Required Paths

# %%
input_path = [i for i in glob('Dataset\*\*\*.mp4')]
# First removing the path by split and then splitting the string to get the label
# output_label = [(i.split("\\")[-1]).split(" ")[1:][0] for i in glob('Dataset\*\*')] 
output_label = [i.split("\\")[-1] for i in glob('Dataset\*\*')] 

print(output_label)
input_path
# Out:
# ['Blind', 'Deaf', 'Flat', 'Happy', 'Poor', 'Quiet', 'Rich', 'sad', 'Slow', 'Thick']
# ['Dataset\\Adjectives\\Blind\\Cropped\\1-1.mp4',
#  'Dataset\\Adjectives\\Blind\\Cropped\\1-2.mp4',
#  'Dataset\\Adjectives\\Blind\\Cropped\\1-3.mp4',
#  'Dataset\\Adjectives\\Blind\\Cropped\\1-4.mp4',
#  'Dataset\\Adjectives\\Blind\\Cropped\\1-5.mp4',
#  'Dataset\\Adjectives\\Blind\\Cropped\\1-6.mp4',
#  'Dataset\\Adjectives\\Blind\\Cropped\\1-7.mp4',
#  'Dataset\\Adjectives\\Blind\\Cropped\\1-8.mp4',
#  'Dataset\\Adjectives\\Deaf\\Cropped\\Deaf-1.mp4',
#  'Dataset\\Adjectives\\Deaf\\Cropped\\Deaf-2.mp4',
#  'Dataset\\Adjectives\\Deaf\\Cropped\\Deaf-3.mp4',
#  'Dataset\\Adjectives\\Deaf\\Cropped\\Deaf-4.mp4',
#  'Dataset\\Adjectives\\Deaf\\Cropped\\Deaf-5.mp4',
#  'Dataset\\Adjectives\\Deaf\\Cropped\\Deaf-6.mp4',
#  'Dataset\\Adjectives\\Deaf\\Cropped\\Deaf-7.mp4',
#  'Dataset\\Adjectives\\Deaf\\Cropped\\Deaf-8.mp4',
#  'Dataset\\Adjectives\\Flat\\Cropped\\Flat-1.mp4',
#  'Dataset\\Adjectives\\Flat\\Cropped\\Flat-2.mp4',
#  'Dataset\\Adjectives\\Flat\\Cropped\\Flat-3.mp4',
#  'Dataset\\Adjectives\\Flat\\Cropped\\Flat-4.mp4',
#  'Dataset\\Adjectives\\Flat\\Cropped\\Flat-5.mp4',
#  'Dataset\\Adjectives\\Flat\\Cropped\\Flat-6.mp4',
#  'Dataset\\Adjectives\\Flat\\Cropped\\Flat-7.mp4',
#  'Dataset\\Adjectives\\Flat\\Cropped\\Flat-8.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-1.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-10.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-11.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-12.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-13.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-14.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-15.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-2.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-3.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-4.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-5.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-6.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-7.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-8.mp4',
#  'Dataset\\Adjectives\\Happy\\Cropped\\Happy-9.mp4',
#  'Dataset\\Adjectives\\Poor\\Cropped\\Poor-1.mp4',
#  'Dataset\\Adjectives\\Poor\\Cropped\\Poor-2.mp4',
#  'Dataset\\Adjectives\\Poor\\Cropped\\Poor-3.mp4',
#  'Dataset\\Adjectives\\Poor\\Cropped\\Poor-4.mp4',
#  'Dataset\\Adjectives\\Poor\\Cropped\\Poor-5.mp4',
#  'Dataset\\Adjectives\\Poor\\Cropped\\Poor-6.mp4',
#  'Dataset\\Adjectives\\Poor\\Cropped\\Poor-7.mp4',
#  'Dataset\\Adjectives\\Poor\\Cropped\\Poor-8.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-1.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-10.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-11.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-12.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-13.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-14.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-15.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-16.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-17.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-18.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-19.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-2.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-20.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-21.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-3.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-4.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-5.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-6.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-7.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-8.mp4',
#  'Dataset\\Adjectives\\Quiet\\Cropped\\quiet-9.mp4',
#  'Dataset\\Adjectives\\Rich\\Cropped\\Rich-1.mp4',
#  'Dataset\\Adjectives\\Rich\\Cropped\\Rich-2.mp4',
#  'Dataset\\Adjectives\\Rich\\Cropped\\Rich-3.mp4',
#  'Dataset\\Adjectives\\Rich\\Cropped\\Rich-4.mp4',
#  'Dataset\\Adjectives\\Rich\\Cropped\\Rich-5.mp4',
#  'Dataset\\Adjectives\\Rich\\Cropped\\Rich-6.mp4',
#  'Dataset\\Adjectives\\Rich\\Cropped\\Rich-7.mp4',
#  'Dataset\\Adjectives\\Rich\\Cropped\\Rich-8.mp4',
#  'Dataset\\Adjectives\\sad\\Cropped\\sad-1.mp4',
#  'Dataset\\Adjectives\\sad\\Cropped\\sad-2.mp4',
#  'Dataset\\Adjectives\\sad\\Cropped\\sad-3.mp4',
#  'Dataset\\Adjectives\\sad\\Cropped\\sad-4.mp4',
#  'Dataset\\Adjectives\\sad\\Cropped\\sad-5.mp4',
#  'Dataset\\Adjectives\\sad\\Cropped\\sad-6.mp4',
#  'Dataset\\Adjectives\\sad\\Cropped\\sad-7.mp4',
#  'Dataset\\Adjectives\\sad\\Cropped\\sad-8.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-1.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-10.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-11.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-12.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-13.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-14.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-15.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-16.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-17.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-18.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-2.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-3.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-4.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-5.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-6.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-7.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-8.mp4',
#  'Dataset\\Adjectives\\Slow\\Cropped\\Slow-9.mp4',
#  'Dataset\\Adjectives\\Thick\\Cropped\\Thick-1.mp4',
#  'Dataset\\Adjectives\\Thick\\Cropped\\Thick-2.mp4',
#  'Dataset\\Adjectives\\Thick\\Cropped\\Thick-3.mp4',
#  'Dataset\\Adjectives\\Thick\\Cropped\\Thick-4.mp4',
#  'Dataset\\Adjectives\\Thick\\Cropped\\Thick-5.mp4',
#  'Dataset\\Adjectives\\Thick\\Cropped\\Thick-6.mp4',
#  'Dataset\\Adjectives\\Thick\\Cropped\\Thick-7.mp4',
#  'Dataset\\Adjectives\\Thick\\Cropped\\Thick-8.mp4']

# %% [markdown]
# # Loading Video in OpenCV

# %% [markdown]
# # Prepering Mediapipe

# %%
mp_holistic = mp.solutions.holistic 
mp_drawing = mp.solutions.drawing_utils 

mp_utils = utils.MediapipeUtils(mp_holistic, mp_drawing)

# %% [markdown]
# # Collecting MP data

# %%
#Creating dir for each label
try:
    os.mkdir('MP_data',)
    for i in range(len(output_label)):
        os.mkdir(f'MP_data/{output_label[i]}')

except:
    print("Directory already exists")

# %%
holistic = mp_holistic.Holistic(min_detection_confidence=0.7, min_tracking_confidence=0.7)
DATA_PATH = "MP_data\\"

# %%
# Loop through sequences aka videos

for ip in tqdm(input_path):
# for ip in tqdm(paths): # Looping through selected 50 labels
    cap = cv2.VideoCapture(ip)
    all_keypoints = []
    keypoints = np.array(None)
        
       
    while cap.isOpened():           
        # Read feed
        ret, frame = cap.read()
        if not ret:
            break
        
        # Make detections
        image, results = mp_utils.mediapipe_detection(frame, holistic)
            
        #Collecting 3D landmarks for a single frame
        keypoints = mp_utils.extract_keypoints(results)
        all_keypoints.append(keypoints)        

    all_keypoints = np.vstack(all_keypoints)

    # all_avg_keypoints = [[0] * 258] * len(all_keypoints)
    # all_avg_keypoints[0] = all_keypoints[0]
    # all_avg_keypoints[1] = all_keypoints[1]


    # # Finding average of all past 3 keypoint values
    # for keypoint in range(2,len(all_keypoints)):
    #     counter = 0
        
    #     for cordinate_1,cordinate_2,cordinate_3 in zip(all_keypoints[keypoint],all_keypoints[keypoint-1],all_keypoints[keypoint-2]):
    #         avg = (cordinate_1+cordinate_2+cordinate_3)/3

    #         all_avg_keypoints[keypoint][counter] = avg
    #         counter += 1
        
    # Saving Landmarks
    path = ip.split("/")
    
    # Getting Current action of the video
    # action = " ".join((ip.split("\\")[-3]).split(" ")[1:])
    action = (ip.split("\\")[-3])
    
    #Get the sequence number
    sequence = ip.split("\\")[-1][:-4]
    
    npy_path = os.path.join(DATA_PATH, action, sequence)
    print(npy_path)
    
    np.save(npy_path, all_keypoints)

    cap.release()
# Out:
#   0%|          | 0/110 [00:00<?, ?it/s]
# MP_data\Blind\1-1
# MP_data\Blind\1-2
# MP_data\Blind\1-3
# MP_data\Blind\1-4
# MP_data\Blind\1-5
# MP_data\Blind\1-6
# MP_data\Blind\1-7
# MP_data\Blind\1-8
# MP_data\Deaf\Deaf-1
# MP_data\Deaf\Deaf-2
# MP_data\Deaf\Deaf-3
# MP_data\Deaf\Deaf-4
# MP_data\Deaf\Deaf-5
# MP_data\Deaf\Deaf-6
# MP_data\Deaf\Deaf-7
# MP_data\Deaf\Deaf-8
# MP_data\Flat\Flat-1
# MP_data\Flat\Flat-2
# MP_data\Flat\Flat-3
# MP_data\Flat\Flat-4
# MP_data\Flat\Flat-5
# MP_data\Flat\Flat-6
# MP_data\Flat\Flat-7
# MP_data\Flat\Flat-8
# MP_data\Happy\Happy-1
# MP_data\Happy\Happy-10
# MP_data\Happy\Happy-11
# MP_data\Happy\Happy-12
# MP_data\Happy\Happy-13
# MP_data\Happy\Happy-14
# MP_data\Happy\Happy-15
# MP_data\Happy\Happy-2
# MP_data\Happy\Happy-3
# MP_data\Happy\Happy-4
# MP_data\Happy\Happy-5
# MP_data\Happy\Happy-6
# MP_data\Happy\Happy-7
# MP_data\Happy\Happy-8
# MP_data\Happy\Happy-9
# MP_data\Poor\Poor-1
# MP_data\Poor\Poor-2
# MP_data\Poor\Poor-3
# MP_data\Poor\Poor-4
# MP_data\Poor\Poor-5
# MP_data\Poor\Poor-6
# MP_data\Poor\Poor-7
# MP_data\Poor\Poor-8
# MP_data\Quiet\quiet-1
# MP_data\Quiet\quiet-10
# MP_data\Quiet\quiet-11
# MP_data\Quiet\quiet-12
# MP_data\Quiet\quiet-13
# MP_data\Quiet\quiet-14
# MP_data\Quiet\quiet-15
# MP_data\Quiet\quiet-16
# MP_data\Quiet\quiet-17
# MP_data\Quiet\quiet-18
# MP_data\Quiet\quiet-19
# MP_data\Quiet\quiet-2
# MP_data\Quiet\quiet-20
# MP_data\Quiet\quiet-21
# MP_data\Quiet\quiet-3
# MP_data\Quiet\quiet-4
# MP_data\Quiet\quiet-5
# MP_data\Quiet\quiet-6
# MP_data\Quiet\quiet-7
# MP_data\Quiet\quiet-8
# MP_data\Quiet\quiet-9
# MP_data\Rich\Rich-1
# MP_data\Rich\Rich-2
# MP_data\Rich\Rich-3
# MP_data\Rich\Rich-4
# MP_data\Rich\Rich-5
# MP_data\Rich\Rich-6
# MP_data\Rich\Rich-7
# MP_data\Rich\Rich-8
# MP_data\sad\sad-1
# MP_data\sad\sad-2
# MP_data\sad\sad-3
# MP_data\sad\sad-4
# MP_data\sad\sad-5
# MP_data\sad\sad-6
# MP_data\sad\sad-7
# MP_data\sad\sad-8
# MP_data\Slow\Slow-1
# MP_data\Slow\Slow-10
# MP_data\Slow\Slow-11
# MP_data\Slow\Slow-12
# MP_data\Slow\Slow-13
# MP_data\Slow\Slow-14
# MP_data\Slow\Slow-15
# MP_data\Slow\Slow-16
# MP_data\Slow\Slow-17
# MP_data\Slow\Slow-18
# MP_data\Slow\Slow-2
# MP_data\Slow\Slow-3
# MP_data\Slow\Slow-4
# MP_data\Slow\Slow-5
# MP_data\Slow\Slow-6
# MP_data\Slow\Slow-7
# MP_data\Slow\Slow-8
# MP_data\Slow\Slow-9
# MP_data\Thick\Thick-1
# MP_data\Thick\Thick-2
# MP_data\Thick\Thick-3
# MP_data\Thick\Thick-4
# MP_data\Thick\Thick-5
# MP_data\Thick\Thick-6
# MP_data\Thick\Thick-7
# MP_data\Thick\Thick-8

# %%
# Applying an algo to filter 50 labels and there addresses
input_path = glob('Dataset\*\*\*.mp4')
include_50 = [i.split("\\")[-1] for i in glob('MP_Data\*')]    

print(input_path)

input_label = list(set([" ".join((i.split("\\")[-2]).split(" ")[1:]) for i in input_path]))

print(input_label)

labels = []
for i in input_label:
    if i in include_50:
        labels.append(i)

paths = []
for i in input_path:
     if (" ".join((i.split("\\")[-2]).split(" ")[1:])) in include_50:
        paths.append(i)

print(len(labels),len(paths))
